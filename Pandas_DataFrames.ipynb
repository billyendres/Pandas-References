# %%
#Data Frames - A group of Pandas Series objects that share the same index

# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(101)
my_data = np.random.randint(0, 101, (4, 3))

# %%
my_data
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
my_index = ['QLD', 'NT', 'NSW', 'VIC']

# %%
my_columns = ['Jan', 'Feb', 'Mar']

# %%
df = pd.DataFrame(my_data, my_index, my_columns)

# %%
df #df.info() - To see information about data frame
# Out:
#      Jan  Feb  Mar
# QLD   95   11   81
# NT    70   63   87
# NSW   75    9   77
# VIC   40    4   63

# %%
pwd #Read in CSV file
# Out:
# 'C:\\Users\\billy\\Desktop\\Jupyter Notebooks\\Pandas'

# %%
df = pd.read_csv('C:\\Users\\billy\\Desktop\\Python Finance\\03-Core-Pandas\\tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#df.column
#df.index
#df.info()
#df.head()/df.tail() - shows first/last 5 rows by default

# %%
df.describe()
#df.describe().transpose() #Transpose swaps rows and columns, easier to read
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
#Working with Columns

# %%
df[['total_bill', 'tip']].transpose()
# Out:
#               0      1      2      3      4      5     6      7      8    \
# total_bill  16.99  10.34  21.01  23.68  24.59  25.29  8.77  26.88  15.04
# tip          1.01   1.66   3.50   3.31   3.61   4.71  2.00   3.12   1.96
#
#               9    ...    234    235   236    237    238    239    240    241  \
# total_bill  14.78  ...  15.53  10.07  12.6  32.83  35.83  29.03  27.18  22.67
# tip          3.23  ...   3.00   1.25   1.0   1.17   4.67   5.92   2.00   2.00
#
#               242    243
# total_bill  17.82  18.78
# tip          1.75   3.00
#
# [2 rows x 244 columns]

# %%
#Create a column with percentage tip in accordance with the total bill & then create new column with results - Round with np. round

# %%
df['tip_percentage'] = np.round(100 * df['tip'] / df['total_bill'], 2)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959            5.94
# 1      Douglas Tucker  4478071379779230    Sun4608           16.05
# 2      Travis Walters  6011812112971322    Sun4458           16.66
# 3    Nathaniel Harris  4676137647685994    Sun5260           13.98
# 4        Tonya Carter  4832732618637221    Sun2251           14.68

# %%
#Drop - axis=0 drops ad row, axis=1 drops as column

# %%
df.drop('tip_percentage', axis=1) #Does not permanently drop the column/row - df = df.drop('tip_percentage', axis=1) for permanent removal
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.shape[1]
# Out:
# 12

# %%
#Working with Indexes (Rows)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
#Set up a specific column as an index

# %%
df.set_index("Payment ID")
df = df.set_index("Payment ID") # permanent change

# %%
df.head()
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No  Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No  Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No  Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No  Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No  Sun  Dinner     4
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# Sun4608                 3.45      Douglas Tucker  4478071379779230
# Sun4458                 7.00      Travis Walters  6011812112971322
# Sun5260                11.84    Nathaniel Harris  4676137647685994
# Sun2251                 6.15        Tonya Carter  4832732618637221
#
#             tip_percentage
# Payment ID
# Sun2959               5.94
# Sun4608              16.05
# Sun4458              16.66
# Sun5260              13.98
# ...

# %%
# df = df.reset_index()

# %%
df = df.set_index("Payment ID")

# %%
df.head()
# Out:
#             level_0  index  total_bill   tip     sex smoker  day    time  \
# Payment ID
# Sun2959           0      0       16.99  1.01  Female     No  Sun  Dinner
# Sun4608           1      1       10.34  1.66    Male     No  Sun  Dinner
# Sun4458           2      2       21.01  3.50    Male     No  Sun  Dinner
# Sun5260           3      3       23.68  3.31    Male     No  Sun  Dinner
# Sun2251           4      4       24.59  3.61  Female     No  Sun  Dinner
#
#             size  price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959        2              8.49  Christy Cunningham  3560325168603410
# Sun4608        3              3.45      Douglas Tucker  4478071379779230
# Sun4458        3              7.00      Travis Walters  6011812112971322
# Sun5260        2             11.84    Nathaniel Harris  4676137647685994
# Sun2251        4              6.15        Tonya Carter  4832732618637221
#
#             tip_percentage
# Payment ID
# ...

# %%
df = df.drop('level_0', axis=1)

# %%
df = df.drop('index', axis=1)

# %%
df.iloc[0] #Integer based index - Can also use slice notation [0:4] etc
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# tip_percentage                    5.94
# Name: Sun2959, dtype: object

# %%
df.loc['Sun4608'] #Name based index - Grab multiple index - [['Sun4608', 'Sun2959']] etc
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# Payer Name            Douglas Tucker
# CC Number           4478071379779230
# tip_percentage                 16.05
# Name: Sun4608, dtype: object

# %%
#Removing Rows

# %%
# df.drop('Sun2959', axis=0)
# df = df.drop('Sun2959', axis=0) - Permanent
# df = df.iloc[5:] - Drop by location

# %%
#Insert new row

# %%
one_row = df.iloc[0] # Has to be correct length and shape to append

# %%
one_row
# Out:
# total_bill                       16.99
# tip                               1.01
# sex                             Female
# smoker                              No
# day                                Sun
# time                            Dinner
# size                                 2
# price_per_person                  8.49
# Payer Name          Christy Cunningham
# CC Number             3560325168603410
# tip_percentage                    5.94
# Name: Sun2959, dtype: object

# %%
df = df.append(one_row) #Added to the end

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
#
#             price_per_person          Payer Name         CC Number  \
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...
